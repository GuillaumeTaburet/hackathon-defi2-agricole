# %%
import xarray as xr
import numpy as np

# %%
ds_data = xr.open_dataset("data/tasminAdjust_FR-Metro_CMCC-CM2-SR5_ssp370_r1i1p1f1_CNRM-MF_CNRM-ALADIN64E1_v1-r1_MF-CDFt-ANASTASIA-SAFRAN-1985-2014_day_20150101-21001231.nc",
                     engine="netcdf4")

# %%
ds_data
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:         (y: 134, x: 143, nbounds: 4, time: 31411, bnds: 2)
# Coordinates:
#     lon             (y, x) float64 153kB ...
#     lat             (y, x) float64 153kB ...
#   * x               (x) float64 1kB 6e+04 6.8e+04 ... 1.188e+06 1.196e+06
#   * y               (y) float64 1kB 1.617e+06 1.625e+06 ... 2.673e+06 2.681e+06
#   * time            (time) datetime64[ns] 251kB 2015-01-01T12:00:00 ... 2100-...
# Dimensions without coordinates: nbounds, bnds
# Data variables:
#     lon_bnds        (y, x, nbounds) float64 613kB ...
#     lat_bnds        (y, x, nbounds) float64 613kB ...
#     LambertParisII  int32 4B ...
#     tasminAdjust    (time, y, x) float32 2GB ...
#     time_bnds       (time, bnds) datetime64[ns] 503kB ...
# Attributes: (12/71)
#     title:                           CNRM-ALADIN64E1 model output corrected o...
#     summary:                         Data were post-processed by the Météo-Fr...
#     id:                              hdl:21.14103/d0c607ca-9e9d-4490-9f34-180...
#     Conventions:                     CF-1.11 ACDD-1.3
#     standard_name_vocabulary:        CF Standard Name Table v81
#     input_domain:                    Europe
#     ...                              ...
#     date_created:                    2025-11-08T06:29:17.012234
#     product:                         bias-adjusted output
#     license:                         https://cordex.org/data-access/cordex-cm...
#     product_version:                 v1
#     comment:                         Preliminary data released in the Fall 20...
#     keywords:                        temperature, climate, France, minimal ne...

# %%
ds_data.tasminAdjust.sel(lon=1.4442, lat=43.6045, method="nearest")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 ds_data.tasminAdjust.sel(lon=1.4442, lat=43.6045, method="nearest")
#
# File /opt/anaconda3/envs/env_hack/lib/python3.10/site-packages/xarray/core/dataarray.py:1682, in DataArray.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1566 def sel(
#    1567     self,
#    1568     indexers: Mapping[Any, Any] | None = None,
#    (...)
#    1572     **indexers_kwargs: Any,
#    1573 ) -> Self:
#    1574     """Return a new DataArray whose data is given by selecting index
#    1575     labels along the specified dimension(s).
#    1576
#    (...)
#    1680     Dimensions without coordinates: points
#    1681     """
# -> 1682     ds = self._to_temp_dataset().sel(
#    1683         indexers=indexers,
#    1684         drop=drop,
#    1685         method=method,
#    1686         tolerance=tolerance,
#    1687         **indexers_kwargs,
#    1688     )
#    1689     return self._from_temp_dataset(ds)
#
# File /opt/anaconda3/envs/env_hack/lib/python3.10/site-packages/xarray/core/dataset.py:2890, in Dataset.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2822 """Returns a new dataset with each array indexed by tick labels
#    2823 along the specified dimension(s).
#    2824
#    (...)
#    2887
#    2888 """
#    2889 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
# -> 2890 query_results = map_index_queries(
#    2891     self, indexers=indexers, method=method, tolerance=tolerance
#    2892 )
#    2894 if drop:
#    2895     no_scalar_variables = {}
#
# File /opt/anaconda3/envs/env_hack/lib/python3.10/site-packages/xarray/core/indexing.py:189, in map_index_queries(obj, indexers, method, tolerance, **indexers_kwargs)
#     186     options = {"method": method, "tolerance": tolerance}
#     188 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "map_index_queries")
# --> 189 grouped_indexers = group_indexers_by_index(obj, indexers, options)
#     191 results = []
#     192 for index, labels in grouped_indexers:
#
# File /opt/anaconda3/envs/env_hack/lib/python3.10/site-packages/xarray/core/indexing.py:148, in group_indexers_by_index(obj, indexers, options)
#     146     grouped_indexers[index_id][key] = label
#     147 elif key in obj.coords:
# --> 148     raise KeyError(f"no index found for coordinate {key!r}")
#     149 elif key not in obj.dims:
#     150     raise KeyError(
#     151         f"{key!r} is not a valid dimension or coordinate for "
#     152         f"{obj.__class__.__name__} with dimensions {obj.dims!r}"
#     153     )
#
# KeyError: "no index found for coordinate 'lon'"

# %%
dist_toulouse = np.sqrt((ds_data.lat - 43.6045)**2 + (ds_data.lon - 1.4442)**2)
idx_min = dist_toulouse.argmin()
(ds_data.tasminAdjust[:,idx_min//143, idx_min%143].sel(time=slice(f"{2033-10}", f"{2034+9}"))<273.15).mean()
# Out:
# <xarray.DataArray 'tasminAdjust' ()> Size: 8B
# array(0.06988266)
# Coordinates:
#     lon      float64 8B 1.396
#     lat      float64 8B 43.64
#     x        float64 8B 5.24e+05
#     y        float64 8B 1.849e+06

# %%
variable='tasminAdjust'
val_data=ds_data[variable].values
moy_data=np.nanmean(val_data, axis=0) #moyenne temporelle
lats_data=ds_data.lat.values #ou ds_data.latitude.values
lons_data=ds_data.lon.values #ou ds_data.longitude.values
# Out:
# /var/folders/_r/hyspm3rx34nf753l6xwvsrg00000gp/T/ipykernel_8468/601147626.py:3: RuntimeWarning: Mean of empty slice
#   moy_data=np.nanmean(val_data,axis=0) #moyenne temporelle

# %% [markdown]
# D'après le fichier : https://console.object.files.data.gouv.fr/browser/meteofrance-drias/OUTILS-HACKATHON-2025%2FTRACC%2F
# on peut obtenir les périodes temporelles pour lesquelles ce modèle entre dans les 3 catégories de la TRACC :
# `CMCC-CM2-SR5_ssp370_r1i1p1f1_CNRM-ALADIN64E1_MF-CDFt-ANASTASIA-SAFRAN-1985-2014 2033, 2050, 2072`
#
# Chaque DATE correspond à l’année centrale de la fenêtre temporelle sur laquelle le modèle atteint l’un des niveaux de réchauffement définis dans la TRACC.
# La fenêtre associée est : [DATE − 10 ; DATE + 9].

# %%
print(lats_data.shape)
# Out:
# (134, 143)

# %%
print(lons_data.shape)
# Out:
# (134, 143)

# %%
print(moy_data.shape)
# Out:
# (134, 143)

# %%
# extraire la série temporelle pour Toulouse (43.6045 N, 1.4442 E)
lat_tlse = 43.6045
lon_tlse = 1.4442
ds_interp = ds_data.interp(lat=lat_tlse,
                           lon=lon_tlse,
                           method="linear")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 4
#       2 lat_tlse = 43.6045
#       3 lon_tlse = 1.4442
# ----> 4 ds_interp = ds_data.interp(lat=lat_tlse, lon=lon_tlse, method="linear")
#
# File /opt/anaconda3/envs/env_hack/lib/python3.10/site-packages/xarray/core/dataset.py:3769, in Dataset.interp(self, coords, method, assume_sorted, kwargs, method_non_numeric, **coords_kwargs)
#    3766     kwargs = {}
#    3768 coords = either_dict_or_kwargs(coords, coords_kwargs, "interp")
# -> 3769 indexers = dict(self._validate_interp_indexers(coords))
#    3770 obj = self if assume_sorted else self.sortby(list(coords))
#    3772 def maybe_variable(obj, k):
#    3773     # workaround to get variable for dimension without coordinate.
#
# File /opt/anaconda3/envs/env_hack/lib/python3.10/site-packages/xarray/core/dataset.py:2570, in Dataset._validate_interp_indexers(self, indexers)
#    2566 def _validate_interp_indexers(
#    2567     self, indexers: Mapping[Any, Any]
#    2568 ) -> Iterator[tuple[Hashable, Variable]]:
#    2569     """Variant of _validate_indexers to be used for interpolation"""
# -> 2570     for k, v in self._validate_indexers(indexers):
#    2571         if isinstance(v, Variable):
#    2572             yield k, v
#
# File /opt/anaconda3/envs/env_hack/lib/python3.10/site-packages/xarray/core/dataset.py:2534, in Dataset._validate_indexers(self, indexers, missing_dims)
#    2531 from xarray.coding.cftimeindex import CFTimeIndex
#    2532 from xarray.core.dataarray import DataArray
# -> 2534 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    2536 # all indexers should be int, slice, np.ndarrays, or Variable
#    2537 for k, v in indexers.items():
#
# File /opt/anaconda3/envs/env_hack/lib/python3.10/site-packages/xarray/core/utils.py:853, in drop_dims_from_indexers(indexers, dims, missing_dims)
#     851     invalid = indexers.keys() - set(dims)
#     852     if invalid:
# --> 853         raise ValueError(
#     854             f"Dimensions {invalid} do not exist. Expected one or more of {dims}"
#     855         )
#     857     return indexers
#     859 elif missing_dims == "warn":
#     860     # don't modify input
#
# ValueError: Dimensions {'lat', 'lon'} do not exist. Expected one or more of FrozenMappingWarningOnValuesAccess({'y': 134, 'x': 143, 'nbounds': 4, 'time': 31411, 'bnds': 2})
